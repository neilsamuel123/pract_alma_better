# %% [markdown]
# <a href="https://colab.research.google.com/github/neilsamuel123/pract_alma_better/blob/main/Airbnb_Bookings_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts) behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. </b>
#
# ## <b>This dataset has around 49,000 observations in it with 16 columns and it is a mix between categorical and numeric values. </b>
#
# ## <b> Explore and analyze the data to discover key understandings (not limited to these) such as :

# %%
# Importing all the packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# The path airbnb dataset is located
path='/content/drive/MyDrive/Colab Notebooks/MODULE1:Python_For_DataScience/airbnb_capstone/Airbnb NYC 2019.csv'

# %%
plt.rcParams['font.size'] = '11'

# %%
# reading the air bnb data set
airbnb_data=pd.read_csv(path)

# %%
# Getting the first 5 rows
airbnb_data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Getting the shape of data
airbnb_data.shape
# Out:
# (48895, 16)

# %%
# To know type of data
airbnb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
# To know the statistic values of dataset
airbnb_data.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
# To check if the dataset has null values
airbnb_data.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# dealing with NaN values
airbnb_data['reviews_per_month'].fillna(0,inplace=True)

# %%
airbnb_data.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# to know the colummn names
airbnb_data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# **id** : a unique id identifying an airbnb lisitng
# **name **: name representating the accomodation
# **host_id** : a unique id identifying an airbnb host
# **host_name** : name under whom host is registered
# **neighbourhood_group** : a group of area
# **beighbourhood** : area falls under neighbourhood_group
# **latitude** : coordinate of listing
# **longitude** : coordinate of listing
# **room_type **: type to categorize listing rooms
# **price** : price of listing
# **minimum_nights** : the minimum nights required to stay in a single visit
# **number_of_reviews** : total count of reviews given by visitors
# **last_review** : date of last review given
# **reviews_per_month** : rate of reviews given per month
# **calculated_host_listings_count** : total no of listing registered under the host
# **availability_365** : the number of days for which a host is available in a year.

# %%
# To get requesite columns
data=airbnb_data[['id', 'name', 'host_id', 'host_name', 'neighbourhood_group','neighbourhood', 'room_type', 'price','minimum_nights', 'number_of_reviews','reviews_per_month', 'calculated_host_listings_count','availability_365','last_review']]

# %%
# To check the first five rows of the dataset
data['total_price']=data['minimum_nights']*data['price']
data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood        room_type  price  \
# 0         John            Brooklyn    Kensington     Private room    149
# ...

# %%
data['neighbourhood_group'].value_counts().sum()
# Out:
# 48895

# %%
plt.figure(figsize=(15,5))
sns.countplot('neighbourhood_group',data=data)
plt.title("Total properties across neighbourhood_group")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Total properties across neighbourhood_group')

# %% [markdown]
# # Manhattan has the highest count of properties around 22000

# %%
# Types of rooms in neighbourhood_groups
plt.figure(figsize=(15,5))
sns.countplot(x='neighbourhood_group',hue='room_type',data=data)
plt.title("Total Count of Properties in the neighbourhood group")
# Out:
# Text(0.5, 1.0, 'Total Count of Properties in the neighbourhood group')

# %%
# Price of neighbourhood group
plt.figure(figsize=(15,5))
sns.barplot(x='neighbourhood_group',y='price',hue='room_type',data=data)
plt.title("Price of each room type")
# Out:
# Text(0.5, 1.0, 'Price of each room type')

# %%
# Minimum Nights of room neighbourhood group
plt.figure(figsize=(15,5))
sns.barplot(x='neighbourhood_group',y='minimum_nights',hue='room_type',data=data)
plt.title("minimum number of nights required to rent the place")
# Out:
# Text(0.5, 1.0, 'minimum number of nights required to rent the place')

# %%
# Total price = mimimum_nights*price
plt.figure(figsize=(15,5))
sns.barplot(x='neighbourhood_group',y='total_price',hue='room_type',data=data)
plt.title("Total Price = minimum nights * price")
# Out:
# Text(0.5, 1.0, 'Total Price = minimum nights * price')

# %%
# Availability of  of room neighbourhood group
plt.figure(figsize=(15,5))
sns.barplot(x='neighbourhood_group',y='availability_365',hue='room_type',data=data)
plt.title("Availability of rooms in a year")
# Out:
# Text(0.5, 1.0, 'Availability of rooms in a year')

# %%
brooklyn_data=data[data['neighbourhood_group']=='Brooklyn']
brooklyn_data.head()
# Out:
#       id                                            name  host_id  \
# 0   2539              Clean & quiet apt home by the park     2787
# 3   3831                 Cozy Entire Floor of Brownstone     4869
# 6   5121                                 BlissArtsSpace!     7356
# 12  5803  Lovely Room 1, Garden, Best Area, Legal rental     9744
# 15  6848                Only 2 stops to Manhattan studio    15991
#
#         host_name neighbourhood_group       neighbourhood        room_type  \
# 0            John            Brooklyn          Kensington     Private room
# 3     LisaRoxanne            Brooklyn        Clinton Hill  Entire home/apt
# 6           Garon            Brooklyn  Bedford-Stuyvesant     Private room
# 12         Laurie            Brooklyn         South Slope     Private room
# 15  Allen & Irina            Brooklyn        Williamsburg  Entire home/apt
#
#     price  minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
# Total hosts in brooklyn and their properties
brooklyn_hosts=brooklyn_data.groupby(['host_name','room_type'])['calculated_host_listings_count'].max().astype(int).reset_index()
brooklyn_hosts.sort_values(by ='calculated_host_listings_count',ascending=False,inplace=True)
top10_hosts_brooklyn=brooklyn_hosts.head(10)
top10_hosts_brooklyn
# Out:
#        host_name        room_type  calculated_host_listings_count
# 926   Blueground  Entire home/apt                             232
# 3794      Kazuya     Private room                             103
# 3837         Ken  Entire home/apt                              87
# 7276        Vida  Entire home/apt                              52
# 6737        Stat     Private room                              43
# 2836      Hiroki     Private room                              37
# 4921     Melissa      Shared room                              34
# 4920     Melissa     Private room                              34
# 4919     Melissa  Entire home/apt                              34
# 526       Anting     Private room                              33

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='host_name',y='calculated_host_listings_count',hue='room_type',data=top10_hosts_brooklyn)
plt.title("The hosts with the most number of properties in Brooklyn Neighbourhood Group")
# Out:
# Text(0.5, 1.0, 'The hosts with the most number of properties in Brooklyn Neighbourhood Group')

# %%
# Total hosts in brooklyn and their properties
brooklyn_likeable_hosts=brooklyn_data.groupby(['host_name','room_type'])['number_of_reviews'].max().astype(int).reset_index()
brooklyn_likeable_hosts.sort_values(by ='number_of_reviews',ascending=False,inplace=True)
top10_hosts_likeable_brooklyn=brooklyn_likeable_hosts.head(10)
top10_hosts_likeable_brooklyn
# Out:
#         host_name        room_type  number_of_reviews
# 628           Asa  Entire home/apt                488
# 7348        Wanda     Private room                480
# 1584         Dani  Entire home/apt                467
# 7341     Waldemar     Private room                426
# 3177  Janet-David  Entire home/apt                404
# 1730       Dennis     Private room                401
# 2196       Evelyn  Entire home/apt                398
# 840      Benjamin     Private room                397
# 355          Amia  Entire home/apt                385
# 3071         J. E  Entire home/apt                378

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='host_name',y='number_of_reviews',hue='room_type',data=top10_hosts_likeable_brooklyn)
plt.title("Most likeable and busy hosts in the Brooklyn Neighbourhood group")
# Out:
# Text(0.5, 1.0, 'Most likeable and busy hosts in the Brooklyn Neighbourhood group')

# %%
Asa_data=data[data['host_name']=='Asa']
Asa_data
# Out:
#            id                                name   host_id host_name  \
# 4870  3474320  Private brownstone studio Brooklyn  12949460       Asa
#
#      neighbourhood_group neighbourhood        room_type  price  \
# 4870            Brooklyn    Park Slope  Entire home/apt    160
#
#       minimum_nights  number_of_reviews  reviews_per_month  \
# 4870               1                488               8.14
#
#       calculated_host_listings_count  availability_365 last_review  \
# 4870                               1               269  2019-07-01
#
#       total_price
# 4870          160

# %%
corr=brooklyn_data.corr()
plt.figure(figsize=(10,5))
sns.heatmap(corr,annot=True)
plt.title("Correlation Map of Brooklyn dataset")
# Out:
# Text(0.5, 1.0, 'Correlation Map of Brooklyn dataset')

# %% [markdown]
# #### 1.Host with the most number of properties in brooklyn is Blueground with a   property of entirehome/apt
# #### 2.Axa is the most likable hosts(price is 160$, minimum night =1 and Asa owns only apartments and available for 269 days
# #### 3. price is inversely proportional to reviews
# #### 4. reviews are directly proportional to availabilty of rooms

# %%
# Manhattan 
manhattan_data=data[data['neighbourhood_group']=='Manhattan']
manhattan_data.head()
# Out:
#      id                                              name  host_id  host_name  \
# 1  2595                             Skylit Midtown Castle     2845   Jennifer
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192      Laura
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322      Chris
# 7  5178                  Large Furnished Room Near B'way      8967   Shunichi
#
#   neighbourhood_group   neighbourhood        room_type  price  minimum_nights  \
# 1           Manhattan         Midtown  Entire home/apt    225               1
# 2           Manhattan          Harlem     Private room    150               3
# 4           Manhattan     East Harlem  Entire home/apt     80              10
# 5           Manhattan     Murray Hill  Entire home/apt    200               3
# 7           Manhattan  Hell's Kitchen     Private room     79               2
#
# ...

# %%
# Total hosts in manhattan and their properties
manhattan_hosts=manhattan_data.groupby(['host_name','room_type'])['calculated_host_listings_count'].max().astype(int).reset_index()
manhattan_hosts.sort_values(by ='calculated_host_listings_count',ascending=False,inplace=True)
top10_hosts_manhattan=manhattan_hosts.head(10)
top10_hosts_manhattan
# Out:
#               host_name        room_type  calculated_host_listings_count
# 6458       Sonder (NYC)     Private room                             327
# 6457       Sonder (NYC)  Entire home/apt                             327
# 913          Blueground  Entire home/apt                             232
# 3610               Kara  Entire home/apt                             121
# 3719             Kazuya  Entire home/apt                             103
# 3720             Kazuya     Private room                             103
# 6456             Sonder  Entire home/apt                              96
# 3223     Jeremy & Laura     Private room                              96
# 3222     Jeremy & Laura  Entire home/apt                              96
# 1472  Corporate Housing  Entire home/apt                              91

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='host_name',y='calculated_host_listings_count',hue='room_type',data=top10_hosts_manhattan)
plt.title("Hosts with the most number of properties in the Manhattan Neighbourhood Group")
# Out:
# Text(0.5, 1.0, 'Hosts with the most number of properties in the Manhattan Neighbourhood Group')

# %%
# Total hosts in brooklyn and their properties
manhattan_likeable_hosts=manhattan_data.groupby(['host_name','room_type'])['number_of_reviews'].max().astype(int).reset_index()
manhattan_likeable_hosts.sort_values(by ='number_of_reviews',ascending=False,inplace=True)
top10_hosts_likeable_manhattan=manhattan_likeable_hosts.head(10)
top10_hosts_likeable_manhattan
# Out:
#      host_name        room_type  number_of_reviews
# 3314        Jj     Private room                607
# 1157     Carol     Private room                540
# 113      Agnes     Private room                458
# 3362      John     Private room                451
# 3381       Jon  Entire home/apt                447
# 6372  Shunichi     Private room                430
# 6212      Seth     Private room                414
# 6182     Seith  Entire home/apt                403
# 4801   Michael  Entire home/apt                401
# 6435       Sne     Private room                396

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='host_name',y='number_of_reviews',hue='room_type',data=top10_hosts_likeable_manhattan)
plt.title("Hosts who are the most likeable and busiest in the Manhattan neighbourhood group")
# Out:
# Text(0.5, 1.0, 'Hosts who are the most likeable and busiest in the Manhattan neighbourhood group')

# %%
data_Jj=data[data['host_name']=='Jj']
data_Jj
# Out:
#              id                                               name    host_id  \
# 1029     424667  Luxury room + En-suite bath in Times Sq/Midtown W    2111060
# 2015     891117                       Private Bedroom in Manhattan    4734398
# 2030     903947                     Beautiful Bedroom in Manhattan    4734398
# 2031     903972                         Great Bedroom in Manhattan    4734398
# 3810    2297029                large 2bdrm apt - midtown manhattan   10974421
# 17995  14094370  Huge Bedroom in Hip Williamsburg Loft-- Bedford L    5242569
# 21605  17317366     Manhattan Midtown Vacation Home away from Home  116870039
# 26234  20914711                           Two Bedroom Pied A Terre    9215509
# 26238  20916679                              Oversized Studio Flat    9215509
# 41224  32065845  Times Square Suite with amazing views, high fl...  240460735
#
#       host_name neighbourhood_group     neighbourhood        room_type  price  \
# ...

# %%
corr=manhattan_data.corr()
plt.figure(figsize=(10,5))
sns.heatmap(corr,annot=True)
plt.title("Correlation map of Manhattan dataset")
# Out:
# Text(0.5, 1.0, 'Correlation map of Manhattan dataset')

# %% [markdown]
# #### 1.Host with the most number of properties in Manhattan is Sonder NYC with a   property of entirehome/apt
# #### 2.Ji is the most likable hosts (private room and private apartment).His most reviewd is aprivate room in Hrlem district,price of this room is 49,minimum nights for renting a room is 1.
# #### 3. price is inversely proportional to reviews
# #### 4. reviews are directly proportional to availabilty of rooms

# %%
# Queens
Queens_data=data[data['neighbourhood_group']=='Queens']
Queens_data.head()
# Out:
#         id                                               name  host_id  \
# 46   12937  1 Stop fr. Manhattan! Private Suite,Landmark B...    50124
# 77   18198                              Little King of Queens    70091
# 143  32363                 Fully Furnished Basement Apartment   140025
# 161  39593            A room w/ a Manhattan view, longer stay   110506
# 181  45910                 Beautiful Queens Brownstone! - 5BR   204539
#
#     host_name neighbourhood_group     neighbourhood        room_type  price  \
# 46    Orestes              Queens  Long Island City     Private room    130
# 77     Justin              Queens          Woodside     Private room     70
# 143    Fredah              Queens          Flushing     Private room    140
# 161     Myung              Queens         Sunnyside     Private room     79
# 181      Mark              Queens         Ridgewood  Entire home/apt    350
#
#      minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
# Total hosts in Queens and their properties
Queens_hosts=Queens_data.groupby(['host_name','room_type'])['calculated_host_listings_count'].max().astype(int).reset_index()
Queens_hosts.sort_values(by ='calculated_host_listings_count',ascending=False,inplace=True)
top10_hosts_Queens=Queens_hosts.head(10)
top10_hosts_Queens
# Out:
#            host_name        room_type  calculated_host_listings_count
# 1443          Kazuya     Private room                             103
# 2567            Stat     Private room                              43
# 1048          Hiroki     Private room                              37
# 223           Anting     Private room                              33
# 2886           Yuval     Private room                              23
# 2203           Petya      Shared room                              18
# 1046  Hillside Hotel     Private room                              18
# 2202           Petya     Private room                              18
# 73              Alan  Entire home/apt                              15
# 2509           Shogo     Private room                              15

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='host_name',y='calculated_host_listings_count',hue='room_type',data=top10_hosts_Queens)
plt.title("Host with most number of properties in the Queen neighbourhood group")
# Out:
# Text(0.5, 1.0, 'Host with most number of properties in the Queen neighbourhood group')

# %%
# Total hosts in Queens and their properties
queens_likeable_hosts=Queens_data.groupby(['host_name','room_type'])['number_of_reviews'].max().astype(int).reset_index()
queens_likeable_hosts.sort_values(by ='number_of_reviews',ascending=False,inplace=True)
top10_hosts_likeable_queens=queens_likeable_hosts.head(10)
top10_hosts_likeable_queens
# Out:
#             host_name        room_type  number_of_reviews
# 684              Dona     Private room                629
# 1855             Maya     Private room                543
# 587          Danielle     Private room                510
# 1613            Linda     Private room                474
# 195            Angela     Private room                466
# 1638            Lloyd      Shared room                454
# 644    Dennis & Naoko  Entire home/apt                441
# 1946          Miss Dy  Entire home/apt                434
# 988   Gurpreet  Singh     Private room                424
# 965      Gladys & Bob  Entire home/apt                414

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='host_name',y='number_of_reviews',hue='room_type',data=top10_hosts_likeable_queens)
plt.title("Hosts who are the most likeable and busiest in the Queen neighbourhood Group")
# Out:
# Text(0.5, 1.0, 'Hosts who are the most likeable and busiest in the Queen neighbourhood Group')

# %%
dona_data=data[data['host_name']=='Dona']
dona_data
# Out:
#              id                     name   host_id host_name  \
# 11759   9145202  Room near JFK Queen Bed  47621202      Dona
# 13495  10101135  Room Near JFK Twin Beds  47621202      Dona
#
#       neighbourhood_group neighbourhood     room_type  price  minimum_nights  \
# 11759              Queens       Jamaica  Private room     47               1
# 13495              Queens       Jamaica  Private room     47               1
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 11759                629              14.58                               2
# 13495                576              13.40                               2
#
#        availability_365 last_review  total_price
# 11759               333  2019-07-05           47
# 13495               173  2019-06-27           47

# %%
corr=Queens_data.corr()
plt.figure(figsize=(10,5))
sns.heatmap(corr,annot=True)
plt.title("Correlation map of Queen dataset")
# Out:
# Text(0.5, 1.0, 'Correlation map of Queen dataset')

# %% [markdown]
# #### 1.Host with the most number of properties in Queens Island is Blueground with a   property of private room
# #### 2.Dona is the most likable hosts(price is 47$, minimum night =1 and Asa owns only privaterooms and available for 333 days
# #### 3. price is inversely proportional to reviews
# #### 4. reviews are directly proportional to availabilty of rooms

# %%
# Staten Islands
staten_data=data[data['neighbourhood_group']=='Staten Island']
staten_data.head()
# Out:
#         id                                name  host_id             host_name  \
# 169  42882           New York room with a view   185978  Newyorkroomwithaview
# 249  62452      A SpeciaL!! Private Room in NY   303939              Lissette
# 250  62461         B NYC Staten Alternative...   303939              Lissette
# 251  62787         C Private Room By The Ferry   303939              Lissette
# 256  63320  D Private Che@p Room 2 Explore NYC   303939              Lissette
#
#     neighbourhood_group  neighbourhood     room_type  price  minimum_nights  \
# 169       Staten Island     St. George  Private room     70               2
# 249       Staten Island  Tompkinsville  Private room     36               2
# 250       Staten Island  Tompkinsville  Private room     37               2
# 251       Staten Island  Tompkinsville  Private room     37               2
# 256       Staten Island  Tompkinsville  Private room     36               2
#
# ...

# %%
# Total hosts in staten and their properties
staten_hosts=staten_data.groupby(['host_name','room_type'])['calculated_host_listings_count'].max().astype(int).reset_index()
staten_hosts.sort_values(by ='calculated_host_listings_count',ascending=False,inplace=True)
top10_hosts_staten=staten_hosts.head(10)
top10_hosts_staten
# Out:
#       host_name        room_type  calculated_host_listings_count
# 13    Amarjit S     Private room                               8
# 174        Nina     Private room                               7
# 11     Amardeep     Private room                               7
# 207  Simranjeet      Shared room                               7
# 206  Simranjeet     Private room                               7
# 175        Nina      Shared room                               7
# 173        Nina  Entire home/apt                               7
# 12     Amardeep      Shared room                               7
# 51         Dine  Entire home/apt                               6
# 52         Dine     Private room                               6

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='host_name',y='calculated_host_listings_count',hue='room_type',data=top10_hosts_staten)
plt.title("Hosts with the most number of properties in the Staten island")
# Out:
# Text(0.5, 1.0, 'Hosts with the most number of properties in the Staten island')

# %%
# Total hosts in staten and their properties
staten_likeable_hosts=staten_data.groupby(['host_name','room_type'])['number_of_reviews'].max().astype(int).reset_index()
staten_likeable_hosts.sort_values(by ='number_of_reviews',ascending=False,inplace=True)
top10_hosts_likeable_staten=staten_likeable_hosts.head(10)
top10_hosts_likeable_staten
# Out:
#                 host_name        room_type  number_of_reviews
# 123              Lissette     Private room                333
# 24                Aurelie  Entire home/apt                242
# 196              Rob&Elle     Private room                234
# 223                 Tonia  Entire home/apt                196
# 42                  David  Entire home/apt                177
# 171  Newyorkroomwithaview     Private room                166
# 6                    Alex     Private room                157
# 80     Hans, Sandra & Son     Private room                151
# 128               Mahmood     Private room                149
# 161        Mona And Wally  Entire home/apt                147

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='host_name',y='number_of_reviews',hue='room_type',data=top10_hosts_likeable_staten)
plt.title("Hosts who are the most likeable and busiest in the Staten Island")
# Out:
# Text(0.5, 1.0, 'Hosts who are the most likeable and busiest in the Staten Island')

# %%
data_lissete=data[data['host_name']=='Lissette']
data_lissete
# Out:
#              id                                name   host_id host_name  \
# 249       62452      A SpeciaL!! Private Room in NY    303939  Lissette
# 250       62461         B NYC Staten Alternative...    303939  Lissette
# 251       62787         C Private Room By The Ferry    303939  Lissette
# 256       63320  D Private Che@p Room 2 Explore NYC    303939  Lissette
# 30967  23996479           #1  Spacious Private Room    303939  Lissette
# 40299  31253968                    Small Room In NY    303939  Lissette
# 40392  31315296     Cozy/Private Room in Park Slope  84796432  Lissette
#
#       neighbourhood_group  neighbourhood     room_type  price  minimum_nights  \
# 249         Staten Island  Tompkinsville  Private room     36               2
# 250         Staten Island  Tompkinsville  Private room     37               2
# 251         Staten Island  Tompkinsville  Private room     37               2
# 256         Staten Island  Tompkinsville  Private room     36               2
# ...

# %%
corr=staten_data.corr()
plt.figure(figsize=(10,5))
sns.heatmap(corr,annot=True)
plt.title("Correlation map of Staten Island Dataset")
# Out:
# Text(0.5, 1.0, 'Correlation map of Staten Island Dataset')

# %% [markdown]
# #### 1.Host with the most number of properties in Staten  is Amarjeet with a   property of private room
# #### 2.Lissette is the most likable hosts(price is 36$, minimum night =2 and Asa owns only apartments and available for 333 days
# #### 3. price is inversely proportional to reviews
# #### 4. reviews are directly proportional to availabilty of rooms

# %%
# Bronx
bronx_data=data[data['neighbourhood_group']=='Bronx']
bronx_data.head()
# Out:
#         id                                              name  host_id  \
# 171  44096                                  Room with a View   190409
# 207  54626                    Cozy bedroom by Yankee Stadium   190409
# 260  63588                                               LL3   295128
# 261  63610  DOMINIQUE'S NY mini efficiency* wifi*metro*quiet   310670
# 309  71812              Condo Apartment with laundry in unit   369015
#
#         host_name neighbourhood_group neighbourhood        room_type  price  \
# 171      Waundell               Bronx    Highbridge     Private room     40
# 207      Waundell               Bronx    Highbridge     Private room     45
# 260  Carol Gloria               Bronx  Clason Point     Private room     90
# 261           Vie               Bronx   Eastchester  Entire home/apt    105
# 309          Thai               Bronx   Kingsbridge  Entire home/apt     90
#
#      minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
# Total hosts in staten and their properties
bronx_hosts=bronx_data.groupby(['host_name','room_type'])['calculated_host_listings_count'].max().astype(int).reset_index()
bronx_hosts.sort_values(by ='calculated_host_listings_count',ascending=False,inplace=True)
top10_hosts_bronx=bronx_hosts.head(10)
top10_hosts_bronx
# Out:
#        host_name        room_type  calculated_host_listings_count
# 287       Hiroki     Private room                              37
# 703          Vie      Shared room                              13
# 702          Vie     Private room                              13
# 701          Vie  Entire home/apt                              13
# 62       Armando     Private room                              10
# 61       Armando  Entire home/apt                              10
# 552     Pi & Leo     Private room                               8
# 536         Orit      Shared room                               8
# 551     Pi & Leo  Entire home/apt                               8
# 411  Lee & Luffy  Entire home/apt                               7

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='host_name',y='calculated_host_listings_count',hue='room_type',data=top10_hosts_bronx)
plt.title("Hosts with the most number of properties in the Bronx Island neighbourhood group")
# Out:
# Text(0.5, 1.0, 'Hosts with the most number of properties in the Bronx Island neighbourhood group')

# %%
# Total hosts in staten and their properties
bronx_likeable_hosts=bronx_data.groupby(['host_name','room_type'])['number_of_reviews'].max().astype(int).reset_index()
bronx_likeable_hosts.sort_values(by ='number_of_reviews',ascending=False,inplace=True)
top10_hosts_likeable_bronx=bronx_likeable_hosts.head(10)
top10_hosts_likeable_bronx
# Out:
#              host_name        room_type  number_of_reviews
# 122            Chandra     Private room                321
# 204            Douglas     Private room                291
# 47                Anne     Private room                276
# 137  Christian & Carla  Entire home/apt                271
# 440               Luis  Entire home/apt                266
# 432               Lori     Private room                258
# 360              Josue  Entire home/apt                227
# 711           Waundell     Private room                219
# 127            Charles  Entire home/apt                206
# 572  Real Estate To Go  Entire home/apt                205

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='host_name',y='number_of_reviews',hue='room_type',data=top10_hosts_likeable_bronx)
plt.title("Hosts who are the most likeable and busiest in the Bronx Island neighbourhood group")
# Out:
# Text(0.5, 1.0, 'Hosts who are the most likeable and busiest in the Bronx Island neighbourhood group')

# %%
data_chandra=data[data['host_name']=='Chandra']
data_chandra
# Out:
#              id                                            name   host_id  \
# 5260    3802218                            Cozy Private Bedroom  19533769
# 25979  20745030  Spacious Room in Sunny Brownstone (Ft. Greene)  23254455
#
#       host_name neighbourhood_group neighbourhood     room_type  price  \
# 5260    Chandra               Bronx    Mott Haven  Private room     53
# 25979   Chandra            Brooklyn  Clinton Hill  Private room     88
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 5260                1                321               5.46
# 25979               2                  0               0.00
#
#        calculated_host_listings_count  availability_365 last_review  \
# 5260                                1                44  2019-06-12
# 25979                               1                 0         NaN
#
#        total_price
# 5260            53
# 25979          176

# %%
corr=bronx_data.corr()
plt.figure(figsize=(10,5))
sns.heatmap(corr,annot=True)
plt.title("Correlation map of Bronx dataset")
# Out:
# Text(0.5, 1.0, 'Correlation map of Bronx dataset')

# %% [markdown]
# #### 1.Host with the most number of properties in Bronx  is Hiroki Privaterooms with a   property of private room
# #### 2.Chandra is the most likable hosts(price is 53$, minimum night =1 and Chandra owns only private_room and available for 43 days
#
# #### 3. price is inversely proportional to reviews
# #### 4. reviews are directly proportional to availabilty of rooms

# %% [markdown]
# # OVERALL HOSTS

# %%
host_highest_listing_area=data.groupby(['host_name','neighbourhood_group','neighbourhood','room_type'])['calculated_host_listings_count'].max().reset_index()
host_highest_listing_area.sort_values(by = 'calculated_host_listings_count',ascending=False,inplace=True)
top100_host_areas=host_highest_listing_area.head(100)

# %%
top100_host_areas
# Out:
#           host_name neighbourhood_group       neighbourhood        room_type  \
# 28583  Sonder (NYC)           Manhattan  Financial District     Private room
# 28581  Sonder (NYC)           Manhattan             Chelsea  Entire home/apt
# 28584  Sonder (NYC)           Manhattan      Hell's Kitchen  Entire home/apt
# 28585  Sonder (NYC)           Manhattan             Midtown  Entire home/apt
# 28586  Sonder (NYC)           Manhattan         Murray Hill  Entire home/apt
# ...             ...                 ...                 ...              ...
# 25005       Pranjal           Manhattan             Chelsea  Entire home/apt
# 25014       Pranjal           Manhattan     Upper West Side  Entire home/apt
# 25009       Pranjal           Manhattan            Kips Bay  Entire home/apt
# 25013       Pranjal           Manhattan     Upper East Side  Entire home/apt
# 25012       Pranjal           Manhattan    Theater District  Entire home/apt
#
#        calculated_host_listings_count
# ...

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='host_name',y='calculated_host_listings_count',data=top100_host_areas)
plt.title("Hosts with the most number of properties in overall neighbourhood group")
# Out:
# Text(0.5, 1.0, 'Hosts with the most number of properties in overall neighbourhood group')

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='host_name',y='calculated_host_listings_count',hue='room_type',data=top100_host_areas)
plt.title("Hosts with the most number of properties(room_type) in overall neighbourhood group")
# Out:
# Text(0.5, 1.0, 'Hosts with the most number of properties(room_type) in overall neighbourhood group')

# %%
sonder_data=data[data['host_name']=='Sonder (NYC)']
sonder_data
# Out:
#              id                                               name    host_id  \
# 38293  30181691      Sonder | 180 Water | Incredible 2BR + Rooftop  219517861
# 38294  30181945         Sonder | 180 Water | Premier 1BR + Rooftop  219517861
# 38588  30347708        Sonder | 180 Water | Charming 1BR + Rooftop  219517861
# 39769  30937590            Sonder | The Nash | Artsy 1BR + Rooftop  219517861
# 39770  30937591        Sonder | The Nash | Lovely Studio + Rooftop  219517861
# ...         ...                                                ...        ...
# 47691  35871510  Sonder | 116 John | Vibrant Studio + Fitness Room  219517861
# 47692  35871511     Sonder | 116 John | Vibrant 1BR + Fitness Room  219517861
# 47693  35871515         Sonder | 116 John | Stunning 1BR + Rooftop  219517861
# 47814  35936418          Sonder | 116 John | Polished Studio + Gym  219517861
# 47821  35937891            Sonder | 116 John | Simple Studio + Gym  219517861
#
# ...

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='host_name',hue='room_type',data=sonder_data)
plt.title("Sonder properties")
# Out:
# Text(0.5, 1.0, 'Sonder properties')

# %% [markdown]
# ## The host with the most property is Sonder NYC mostly Entire Home/Apt
# ## Majority of her rooms is monthly rental(minimum nights is 29 days)

# %%
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood        room_type  price  \
# 0         John            Brooklyn    Kensington     Private room    149
# 1     Jennifer           Manhattan       Midtown  Entire home/apt    225
# 2    Elisabeth           Manhattan        Harlem     Private room    150
# 3  LisaRoxanne            Brooklyn  Clinton Hill  Entire home/apt     89
# 4        Laura           Manhattan   East Harlem  Entire home/apt     80
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0               1                  9               0.21
# ...

# %%
# Which neighbour hood group gives the most reviews per month
most_neighbourhood_review=data.groupby('neighbourhood_group')['reviews_per_month'].max().astype(int).reset_index()
most_neighbourhood_review.sort_values(by = 'reviews_per_month',ascending=False,inplace=True)
most_neighbourhood_review
# Out:
#   neighbourhood_group  reviews_per_month
# 2           Manhattan                 58
# 3              Queens                 20
# 1            Brooklyn                 14
# 0               Bronx                 10
# 4       Staten Island                 10

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='neighbourhood_group',y='reviews_per_month',data=most_neighbourhood_review)
plt.title("Most number of reviews across neighbourhood groups")
# Out:
# Text(0.5, 1.0, 'Most number of reviews across neighbourhood groups')

# %% [markdown]
# ## Manhattan is the state which reviews most per month

# %%
data['last_review'] = pd.to_datetime(data['last_review'], errors='coerce')
data['Days'], data['Month'], data['Years'] = (data['last_review'].dt.day, data['last_review'].dt.month, data['last_review'].dt.year)
data['last_review'] = pd.to_datetime(data['last_review']).dt.date
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#  converted to date, null column date becomes system min date i.e. 1970-01-01
#  removing these datas
filtered_df = data[data['Years'] != 1970]

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(22, 6))
ax = axes.flatten()

sns.histplot(data=filtered_df, x='Days', hue='room_type', multiple="stack", ax=ax[0])
ax[0].set_title('No of Guest in days of the months')
sns.histplot(data=filtered_df, x='Month', hue='room_type', multiple="stack", ax=ax[1])
ax[0].set_title('No of Guest in months of the years')
sns.despine(fig, left=True)

# %% [markdown]
# ## So, we've created day month based on the last_review date, it is not fully accurate many guest prefer to not give a rating (assuming).
# ## We can see a trend where, first day and last day of month most number of guests.
# ## Also in the middle of the year, in June Month, there is a surge in guest count.

# %%
review_price = data.groupby(['price'])['number_of_reviews'].max().reset_index()
review_price.sort_values(by = 'number_of_reviews',ascending=False,inplace=True)
review_price
# Out:
#      price  number_of_reviews
# 36      47                629
# 38      49                607
# 35      46                543
# 88      99                540
# 37      48                510
# ..     ...                ...
# 540    830                  0
# 538    822                  0
# 531    794                  0
# 280    292                  0
# 508    680                  0
#
# [674 rows x 2 columns]

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(x='price',y='number_of_reviews',data=review_price)
plt.title("Price vs Number_of_Reviews")
# Out:
# Text(0.5, 1.0, 'Price vs Number_of_Reviews')

# %%
## Different view of the above plots 
## price vs review
## review vs neighbourhood groups
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(22, 6))
ax = axes.flatten()

sns.lineplot(data=data, x='neighbourhood_group', y='reviews_per_month', hue='room_type', style="room_type",
        markers=True, dashes=False, ax=ax[0])
ax[0].set_title('Review per Month vs Neighbourhoods')
sns.scatterplot(data=data, x='number_of_reviews', y='price', hue='room_type', palette="ch:r=-.2,d=.3_r",
        hue_order=['Private room', 'Shared room', 'Entire home/apt'], ax=ax[1])
ax[1].set_title('Price vs Number of Reviews')
sns.despine(fig, left=True)

# %% [markdown]
# ## Price isnt correlated(negatively correlated) with reviews

# %%
# Which neighbour hood group gives the most available rooms
review_availablity=data.groupby('availability_365')['number_of_reviews'].max().astype(int).reset_index()
review_availablity.sort_values(by = 'number_of_reviews',ascending=False,inplace=True)
review_availablity
# Out:
#      availability_365  number_of_reviews
# 333               333                629
# 293               293                607
# 342               342                597
# 339               339                594
# 173               173                576
# ..                ...                ...
# 113               113                127
# 119               119                125
# 101               101                123
# 138               138                115
# 190               190                109
#
# [366 rows x 2 columns]

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(x='availability_365',y='number_of_reviews',data=review_availablity)
plt.title("Availability_365 vs Number_of_Reviews")
# Out:
# Text(0.5, 1.0, 'Availability_365 vs Number_of_Reviews')

# %% [markdown]
# ## The more the number of availability days of rooms, the more are the reviews

# %%
## Price vs minimum nights
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(22, 6))
ax = axes.flatten()

mean_price_df = data.groupby(['neighbourhood_group', 'room_type'], as_index=False)[['minimum_nights']].mean()
sns.barplot(data=mean_price_df, x='neighbourhood_group', y='minimum_nights', hue='room_type', palette='GnBu_d', ax=ax[0])
ax[0].set_title("Avg Minimum Nights vs Neighbourhood / Room Type");

sns.scatterplot(data=data[data['price'] < 1000], x='minimum_nights', y='price', hue='room_type', palette="ch:r=-.2,d=.3_r", ax=ax[1])
ax[1].set_title("Price vs Minimum Nights (Range $ 0 - 1000)")

sns.despine(fig)

# %% [markdown]
# ## We can see, the more cost the property has, the more it tends to allow lower number of minimum nights
# ## Within the price range 0 - 200, the minimum nights distribution is ranged between approx 0 - 400 days.
# ## But within the price range $ 600 - 1000, avg minimum nights decreased to ~7 nights.
# ## But still, we can say most hosts gives less than 10 nights mandatory stay.As a trivia, Manhattan has highest avg minimum night restriction

# %%
# the most likebale hosts
likeble_hosts=data.groupby('host_name')[['number_of_reviews','reviews_per_month']].max().astype(int).reset_index()
likeble_hosts.sort_values(by = ['number_of_reviews','reviews_per_month'],ascending=[False,False],inplace=True)
likeble_hosts
# Out:
#       host_name  number_of_reviews  reviews_per_month
# 2652       Dona                629                 14
# 4931         Jj                607                  7
# 6981       Maya                543                 11
# 1673      Carol                540                  6
# 2290   Danielle                510                 16
# ...         ...                ...                ...
# 11445        韦达                  0                  0
# 11446        馨惠                  0                  0
# 11447        단비                  0                  0
# 11450         진                  0                  0
# 11451        현선                  0                  0
#
# [11452 rows x 3 columns]

# %%
top_likeble_hosts=likeble_hosts.head(10)

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='host_name',y='number_of_reviews',data=top_likeble_hosts)
plt.title('top likeable hosts across neighbourhood groups')
# Out:
# Text(0.5, 1.0, 'top likeable hosts across neighbourhood groups')

# %%
# the most likebale hosts
likeble_hosts_room=data.groupby(['host_name','room_type'])[['number_of_reviews','reviews_per_month']].max().astype(int).reset_index()
likeble_hosts_room.sort_values(by = ['number_of_reviews','reviews_per_month'],ascending=[False,False],inplace=True)
likeble_hosts_room
# Out:
#       host_name        room_type  number_of_reviews  reviews_per_month
# 3434       Dona     Private room                629                 14
# 6333         Jj     Private room                607                  7
# 8978       Maya     Private room                543                 11
# 2164      Carol     Private room                540                  6
# 2975   Danielle     Private room                510                 16
# ...         ...              ...                ...                ...
# 14582        韦达     Private room                  0                  0
# 14583        馨惠     Private room                  0                  0
# 14584        단비  Entire home/apt                  0                  0
# 14587         진  Entire home/apt                  0                  0
# 14588        현선     Private room                  0                  0
#
# [14589 rows x 4 columns]

# %%
top_likeble_hosts_room=likeble_hosts_room.head(10)

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='host_name',y='number_of_reviews',hue='room_type',data=top_likeble_hosts_room)
plt.title('top likeable hosts across neighbourhood groups with room information')
# Out:
# Text(0.5, 1.0, 'top likeable hosts across neighbourhood groups with room information')

# %%
dona_data=data[data['host_name']=='Dona']
dona_data
# Out:
#              id                     name   host_id host_name  \
# 11759   9145202  Room near JFK Queen Bed  47621202      Dona
# 13495  10101135  Room Near JFK Twin Beds  47621202      Dona
#
#       neighbourhood_group neighbourhood     room_type  price  minimum_nights  \
# 11759              Queens       Jamaica  Private room     47               1
# 13495              Queens       Jamaica  Private room     47               1
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 11759                629              14.58                               2
# 13495                576              13.40                               2
#
#        availability_365 last_review  total_price  Days  Month   Years
# 11759               333  2019-07-05           47   5.0    7.0  2019.0
# 13495               173  2019-06-27           47  27.0    6.0  2019.0

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='host_name',hue='room_type',data=dona_data)
plt.title('Dona properties')
# Out:
# Text(0.5, 1.0, 'Dona properties')

# %% [markdown]
# ##DONA is the most likeable hosts private room costing around 47$ and available for 333 days can be rented per day

# %%
# Which room type is preferred
data['room_type'].value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
data['room_type'].value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
data['room_type'].value_counts().plot(kind='bar')
plt.title("Room types count")
# Out:
# Text(0.5, 1.0, 'Room types count')

# %% [markdown]
# ## entire home and apartment is preferred

# %% [markdown]
# ## People prefer entire home/apt inspite of high prices because of safety concerns

# %%
data_price=data[['neighbourhood_group','price']]
plt.figure(figsize=(15,5))
sns.boxplot(x='neighbourhood_group',y='price',data=data_price)
plt.title("neighbourhood_group vs price")
# Out:
# Text(0.5, 1.0, 'neighbourhood_group vs price')

# %% [markdown]
# ## Neighbourhood_group Outlier(price)
# ## Brooklyn--2500
# ## Manhattan--3000
# ## Queens--2000
# ## Staten_Island--1000
# ## Bronx--500

# %% [markdown]
# ## Since if we combine all the neighbourhood groups then the outliers are greater than 200 USD so we consider the price from 0-200 USD

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(24, 8))
ax = axes.flatten()

sns.lineplot(data=data, x='neighbourhood_group', y='availability_365', hue='room_type', ax=ax[0])
ax[0].set_title('Room Availability throughout Neighbourhood/Room Type')
sns.scatterplot(data=data[data['price'] < 200], x="availability_365", y='price', hue='room_type', alpha=.9, palette="muted", ax=ax[1])
ax[1].set_title('Price vs Availability (Range $ 0 - 200)')

sns.countplot(data=data[data['availability_365']  == 365], x='neighbourhood_group', hue='room_type', palette='GnBu_d', ax=ax[2])
ax[2].set_title('Property Available Whole Year')
sns.despine(fig)

# %%
data_price=data[['neighbourhood_group','price']]
plt.figure(figsize=(15,5))
sns.violinplot(x='neighbourhood_group',y='price',data=data_price)
plt.title("Violin plot neighbourhood_group vs price")
# Out:
# Text(0.5, 1.0, 'Violin plot neighbourhood_group vs price')

# %%
corr=data.corr()
plt.figure(figsize=(10,5))
sns.heatmap(corr,annot=True)
plt.title("Correlation map for entire dataset")
# Out:
# Text(0.5, 1.0, 'Correlation map for entire dataset')

# %%
## different view of correlation map
plt.figure(figsize=(10, 6))
heatmap = sns.heatmap(data.corr(), linewidths=0, vmin=-1, annot=True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# #** Conclusion**
#
# #### NaN values were in majority in the number of reviews column removed for data analysis
# #### Manhattan has the highest count of properties around 22000
#
# ####                     **BROOKLYN**
# #### 1.Host with the most number of properties in brooklyn is Blueground with a   property of entirehome/apt
# #### 2.Axa is the most likable hosts(price is 160$, minimum night =1 and Asa owns only apartments and available for 269 days
# #### 3. price is inversely proportional to reviews
# #### 4. reviews are directly proportional to availabilty of rooms
#
# ####                     **MANHATTAN**
# #### 1.Host with the most number of properties in brooklyn is Blueground with a   property of entirehome/apt
# #### 2.Axa is the most likable hosts(price is 160$, minimum night =1 and Asa owns only apartments and available for 269 days
# #### 3. price is inversely proportional to reviews
# #### 4. reviews are directly proportional to availabilty of rooms
#
# ####                     **QUEENS**
# #### 1.Host with the most number of properties in Queens Island is Blueground with a   property of private room
# #### 2.Dona is the most likable hosts(price is 47$, minimum night =1 and Asa owns only privaterooms and available for 333 days
# #### 3. price is inversely proportional to reviews
# #### 4. reviews are directly proportional to availabilty of rooms
#
# ####                    ** STATEN_ISLANDS**
# #### 1.Host with the most number of properties in Staten  is Amarjeet with a   property of private room
# #### 2.Lissette is the most likable hosts(price is 36$, minimum night =2 and Asa owns only apartments and available for 333 days
# #### 3. price is inversely proportional to reviews
# #### 4. reviews are directly proportional to availabilty of rooms
#
# ####                     **BRONX ISLAND**
#
# #### 1.Host with the most number of properties in Bronx  is Hiroki Privaterooms with a   property of private room
# #### 2.Chandra is the most likable hosts(price is 53$, minimum night =1 and Chandra owns only private_room and available for 43 days
#
# #### 3. price is inversely proportional to reviews
# #### 4. reviews are directly proportional to availabilty of rooms
#
# ####               ** OVERALL NEIGHBOURHOOD GROUP**
# #### The host with the most property is Sonder NYC mostly Entire Home/Apt
# #### Majority of Sonder rooms is monthly rental(minimum nights is 29 days)
# #### Manhattan is the state which reviews most per month
# #### We can see a trend where, first day and last day of month most number of guests.
# #### Also in the middle of the year, in June Month, there is a surge in guest count.
# #### Price is inversely proportional to reviews
# #### The more the number of availability days of rooms, the more are the reviews.
# #####We can see, the more cost the property has, the more it tends to allow lower number of minimum nights
# #### Within the price range 0 - 200, the minimum nights distribution is ranged between approx 0 - 400 days.
# #### But within the price range 600 - 1000 USD, avg minimum nights decreased to ~7 nights.
# #### But still, we can say most hosts gives less than 10 nights mandatory stay.As a trivia, Manhattan has highest avg minimum night restriction
# #### DONA is the most likeable hosts private room costing around 47 USD and available for 333 days can be rented per day
# #### Entire home and apartment is preferred
# ####  People prefer entire home/apt inspite of high prices because of safety concerns
# #### Neighbourhood_group Outlier(price)
# #### Brooklyn--2500
# #### Manhattan--3000
# #### Queens--2000
# #### Staten_Island--1000
# #### Bronx--500
